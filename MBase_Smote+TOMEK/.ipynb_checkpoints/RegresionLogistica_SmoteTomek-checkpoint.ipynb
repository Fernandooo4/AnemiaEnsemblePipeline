# %%
import pandas
print (pandas.__version__)
# Out:
# 2.2.2

# %%
pip list
# Out:
# Package                           VersionNote: you may need to restart the kernel to use updated packages.
#
# --------------------------------- ------------------
# absl-py                           2.2.2
# aext-assistant                    4.0.15
# aext-assistant-server             4.0.15
# aext-core                         4.0.15
# aext-core-server                  4.0.15
# aext-panels                       4.0.15
# aext-panels-server                4.0.15
# aext-share-notebook               4.0.15
# aext-share-notebook-server        4.0.15
# aext-shared                       4.0.15
# aiobotocore                       2.12.3
# aiohttp                           3.9.5
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.0.1
# anaconda-anon-usage               0.4.4
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.5.1
# anaconda-navigator                2.6.0
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# antlr4-python3-runtime            4.9.3
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           6.1.0
# astropy-iers-data                 0.2024.6.3.0.31.14
# asttokens                         2.0.5
# async-lru                         2.0.4
# atomicwrites                      1.4.0
# attrs                             23.1.0
# Automat                           20.2.0
# autopep8                          2.0.4
# Babel                             2.11.0
# bcrypt                            3.2.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# black                             24.4.2
# bleach                            4.1.0
# blinker                           1.6.2
# bokeh                             3.4.1
# boltons                           23.0.0
# botocore                          1.34.69
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# cachetools                        5.3.3
# catboost                          1.2.8
# certifi                           2024.8.30
# cffi                              1.16.0
# chardet                           4.0.0
# charset-normalizer                2.0.4
# click                             8.1.7
# cloudpickle                       2.2.1
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.1
# conda                             24.9.2
# conda-build                       24.5.1
# conda-content-trust               0.2.0
# conda_index                       0.5.0
# conda-libmamba-solver             24.1.0
# conda-pack                        0.7.1
# conda-package-handling            2.3.0
# conda_package_streaming           0.10.0
# conda-repo-cli                    1.0.88
# conda-token                       0.5.0+1.g2209e04
# constantly                        23.10.4
# contourpy                         1.2.0
# cookiecutter                      2.6.0
# cryptography                      42.0.5
# cssselect                         1.2.0
# cycler                            0.11.0
# cytoolz                           0.12.2
# dask                              2024.5.0
# dask-expr                         1.1.0
# datashader                        0.16.2
# debugpy                           1.6.7
# decorator                         5.1.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2024.5.0
# distro                            1.9.0
# docstring-to-markdown             0.11
# docutils                          0.18.1
# einops                            0.7.0
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# executing                         0.8.3
# fastjsonschema                    2.16.2
# filelock                          3.13.1
# flake8                            7.0.0
# Flask                             3.0.3
# fonttools                         4.51.0
# fqdn                              1.5.1
# frozendict                        2.4.2
# frozenlist                        1.4.0
# fsspec                            2024.3.1
# gensim                            4.3.2
# gitdb                             4.0.7
# GitPython                         3.1.37
# graphviz                          0.20.3
# greenlet                          3.0.1
# grpcio                            1.71.0
# h11                               0.14.0
# h5py                              3.11.0
# HeapDict                          1.0.1
# holoviews                         1.19.0
# httpcore                          1.0.2
# httpx                             0.27.0
# huggingface-hub                   0.31.4
# hvplot                            0.10.0
# hyperlink                         21.0.0
# idna                              3.7
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.12.3
# importlib-metadata                7.0.1
# incremental                       22.10.0
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            0.7.0
# intervaltree                      3.1.0
# ipykernel                         6.28.0
# ipython                           8.25.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.8.1
# isoduration                       20.11.0
# isort                             5.13.2
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jedi                              0.18.1
# jellyfish                         1.0.1
# Jinja2                            3.1.4
# jmespath                          1.0.1
# joblib                            1.4.2
# json5                             0.9.6
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.19.2
# jsonschema-specifications         2023.7.1
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.10.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.14.1
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.0.11
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.25.1
# jupyterlab-widgets                1.0.0
# keyring                           24.3.1
# kiwisolver                        1.4.4
# lazy_loader                       0.4
# lazy-object-proxy                 1.10.0
# lckr_jupyterlab_variableinspector 3.1.0
# libarchive-c                      2.9
# libmambapy                        1.5.8
# lightgbm                          4.5.0
# lightning-utilities               0.14.3
# linkify-it-py                     2.0.0
# llvmlite                          0.42.0
# lmdb                              1.4.1
# locket                            1.0.0
# lxml                              5.2.1
# lz4                               4.3.2
# Markdown                          3.4.1
# markdown-it-py                    2.2.0
# MarkupSafe                        2.1.3
# matplotlib                        3.8.4
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.1.1
# missingno                         0.5.2
# mistune                           2.0.4
# mkl-fft                           1.3.8
# mkl-random                        1.2.4
# mkl-service                       2.4.0
# more-itertools                    10.1.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.0.4
# multipledispatch                  0.6.0
# mypy                              1.10.0
# mypy-extensions                   1.0.0
# navigator-updater                 0.5.1
# nbclient                          0.8.0
# nbconvert                         7.10.0
# nbformat                          5.9.2
# nest-asyncio                      1.6.0
# networkx                          3.2.1
# nltk                              3.8.1
# notebook                          7.0.8
# notebook_shim                     0.2.3
# numba                             0.59.1
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.7.0
# omegaconf                         2.3.0
# openpyxl                          3.1.2
# overrides                         7.4.0
# packaging                         23.2
# pandas                            2.2.2
# pandocfilters                     1.5.0
# panel                             1.4.4
# param                             2.1.0
# paramiko                          2.8.1
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# pathspec                          0.10.3
# patsy                             0.5.6
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            10.3.0
# pip                               24.0
# pkce                              1.0.3
# pkginfo                           1.10.0
# platformdirs                      3.10.0
# plotly                            5.22.0
# pluggy                            1.0.0
# ply                               3.11
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.43
# Protego                           0.1.16
# protobuf                          3.20.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyarrow                           14.0.2
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.11.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.2
# pydantic                          2.5.3
# pydantic_core                     2.14.6
# pydeck                            0.8.0
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.4
# pyflakes                          3.2.0
# Pygments                          2.15.1
# PyJWT                             2.8.0
# pylint                            2.16.2
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.0.1
# pyOpenSSL                         24.0.0
# pyparsing                         3.0.9
# PyQt5                             5.15.10
# PyQt5-sip                         12.13.0
# PyQtWebEngine                     5.15.6
# PySocks                           1.7.1
# pytest                            7.4.4
# python-dateutil                   2.9.0.post0
# python-dotenv                     0.21.0
# python-json-logger                2.0.7
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.10.0
# python-slugify                    5.0.2
# python-snappy                     0.6.1
# pytoolconfig                      1.2.6
# pytorch-lightning                 2.4.0
# pytorch-tabnet                    4.1.0
# pytorch-tabular                   1.1.1
# pytz                              2024.1
# pyviz_comms                       3.0.2
# pywavelets                        1.5.0
# pywin32                           305.1
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.10
# PyYAML                            6.0.1
# pyzmq                             25.1.2
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.2.2
# qtconsole                         5.5.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# referencing                       0.30.2
# regex                             2023.10.3
# requests                          2.32.2
# requests-file                     1.5.1
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.3.5
# rope                              1.12.0
# rpds-py                           0.10.6
# Rtree                             1.0.1
# ruamel.yaml                       0.17.21
# ruamel-yaml-conda                 0.17.21
# s3fs                              2024.3.1
# safetensors                       0.5.3
# scikit-image                      0.23.2
# scikit-learn                      1.5.1
# scipy                             1.13.1
# Scrapy                            2.11.1
# seaborn                           0.13.2
# semver                            3.0.2
# Send2Trash                        1.8.2
# service-identity                  18.1.0
# setuptools                        69.5.1
# shap                              0.48.0
# sip                               6.7.12
# six                               1.16.0
# skorch                            1.1.0
# slicer                            0.0.8
# smart-open                        5.2.1
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            7.3.7
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.10
# spyder                            5.5.1
# spyder-kernels                    2.5.0
# SQLAlchemy                        2.0.30
# stack-data                        0.2.0
# statsmodels                       0.14.2
# streamlit                         1.32.0
# sympy                             1.14.0
# tables                            3.9.2
# tabulate                          0.9.0
# tblib                             1.7.0
# tenacity                          8.2.2
# tensorboard                       2.19.0
# tensorboard-data-server           0.7.2
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.2.1
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# timm                              1.0.15
# tinycss2                          1.2.1
# tldextract                        3.2.0
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.11.1
# toolz                             0.12.0
# torch                             2.7.0
# torchmetrics                      1.5.2
# torchvision                       0.22.0
# tornado                           6.4.1
# tqdm                              4.66.4
# traitlets                         5.14.3
# truststore                        0.8.0
# Twisted                           23.10.0
# twisted-iocpsupport               1.0.2
# typing_extensions                 4.11.0
# tzdata                            2023.3
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# unicodedata2                      15.1.0
# Unidecode                         1.2.0
# uri-template                      1.3.0
# urllib3                           2.2.2
# w3lib                             2.1.2
# watchdog                          4.0.1
# wcwidth                           0.2.5
# webcolors                         24.11.1
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# whatthepatch                      1.0.2
# wheel                             0.43.0
# widgetsnbextension                3.6.6
# win-inet-pton                     1.1.0
# wrapt                             1.14.1
# xarray                            2023.6.0
# xgboost                           2.1.2
# xlwings                           0.31.4
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.9.3
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.22.0

# %%
import pandas as pd 
data = "AnemiaTipos.csv"

dataset = pd.read_csv(data)

dataset
# Out:
#         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB       HCT   MCV  \
# 0     10.00  43.200  50.100  4.30000  5.00000  2.77   7.3   24.2000  87.7
# 1     10.00  42.400  52.300  4.20000  5.30000  2.84   7.3   25.0000  88.2
# 2      7.20  30.700  60.700  2.20000  4.40000  3.97   9.0   30.5000  77.0
# 3      6.00  30.200  63.500  1.80000  3.80000  4.22   3.8   32.8000  77.9
# 4      4.20  39.100  53.700  1.60000  2.30000  3.93   0.4  316.0000  80.6
# ...     ...     ...     ...      ...      ...   ...   ...       ...   ...
# 1145   4.40  25.845  77.511  1.88076  5.14094  4.86  13.5   46.1526  80.7
# 1146   5.60  25.845  77.511  1.88076  5.14094  4.85  15.0   46.1526  91.7
# 1147   9.20  25.845  77.511  1.88076  5.14094  4.47  13.1   46.1526  88.7
# 1148   6.48  25.845  77.511  1.88076  5.14094  4.75  13.2   46.1526  86.7
# 1149   8.80  25.845  77.511  1.88076  5.14094  4.95  15.2   46.1526  89.7
#
#        MCH  MCHC    PLT        PDW      PCT                      Diagnosis
# 0     26.3  30.1  189.0  12.500000  0.17000  Normocytic hypochromic anemia
# 1     25.7  20.2  180.0  12.500000  0.16000  Normocytic hypochromic anemia
# 2     22.6  29.5  148.0  14.300000  0.14000         Iron deficiency anemia
# 3     23.2  29.8  143.0  11.300000  0.12000         Iron deficiency anemia
# 4     23.9  29.7  236.0  12.800000  0.22000  Normocytic hypochromic anemia
# ...    ...   ...    ...        ...      ...                            ...
# 1145  27.7  34.4  180.0  14.312512  0.26028                        Healthy
# 1146  31.0  33.8  215.0  14.312512  0.26028                        Healthy
# 1147  29.3  33.0  329.0  14.312512  0.26028                        Healthy
# 1148  27.9  32.1  174.0  14.312512  0.26028                        Healthy
# 1149  30.6  34.2  279.0  14.312512  0.26028                        Healthy
#
# [1150 rows x 15 columns]

# %%
#librerias para el desarrollo del proyecto
import matplotlib.pyplot as plt #libreria para graficas
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
from matplotlib.ticker import StrMethodFormatter
import seaborn as sb

#librerias pandas para el manejo de los datos
import pandas as pd
import pandas as pq
import pandas as pf
import pandas as filtro_filas

#enlazando los datos en el archivo excel
data = pd.read_csv("AnemiaTipos.csv",index_col=None)
import numpy as np
#invocando a la libreria de clasificacion
from sklearn.linear_model import LogisticRegression

# %%
data.shape
# Out:
# (1150, 15)

# %%
data.isnull().sum()
# Out:
# WBC          0
# LYMp         0
# NEUTp        0
# LYMn         0
# NEUTn        0
# RBC          0
# HGB          0
# HCT          0
# MCV          0
# MCH          0
# MCHC         0
# PLT          0
# PDW          0
# PCT          0
# Diagnosis    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1150 entries, 0 to 1149
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   WBC        1150 non-null   float64
#  1   LYMp       1150 non-null   float64
#  2   NEUTp      1150 non-null   float64
#  3   LYMn       1150 non-null   float64
#  4   NEUTn      1150 non-null   float64
#  5   RBC        1150 non-null   float64
#  6   HGB        1150 non-null   float64
#  7   HCT        1150 non-null   float64
#  8   MCV        1150 non-null   float64
#  9   MCH        1150 non-null   float64
#  10  MCHC       1150 non-null   float64
#  11  PLT        1150 non-null   float64
#  12  PDW        1150 non-null   float64
#  13  PCT        1150 non-null   float64
#  14  Diagnosis  1150 non-null   object
# dtypes: float64(14), object(1)
# memory usage: 134.9+ KB

# %%
null_columns=data.columns[data.isnull().any()]

print(null_columns)
# Out:
# Index([], dtype='object')

# %%
import missingno as msno
msno.matrix(data) 
plt.show()

# %%
# captura el numero de filas y columnas
rows = len(data.axes[0])
cols = len(data.axes[1])
# Imprimir el numero de filas y columnas
print("Numero de filas: " + str(rows))
print("Numero de columnas: " + str(cols))
# Out:
# Numero de filas: 1150
# Numero de columnas: 15

# %%
data.isnull().any()
# Devuelve una Serie booleana donde cada columna indica si tiene algún NaN.
# Out:
# WBC          False
# LYMp         False
# NEUTp        False
# LYMn         False
# NEUTn        False
# RBC          False
# HGB          False
# HCT          False
# MCV          False
# MCH          False
# MCHC         False
# PLT          False
# PDW          False
# PCT          False
# Diagnosis    False
# dtype: bool

# %%
#Verificamos cuantos tipos de "ANEMIA" hay :V
print(data.groupby('Diagnosis').size())
# Out:
# Diagnosis
# Healthy                           336
# Iron deficiency anemia            189
# Macrocytic anemia                  18
# Normocytic hypochromic anemia     279
# Normocytic normochromic anemia    269
# Other microcytic anemia            59
# dtype: int64

# %%
import seaborn as sb

sb.catplot(x='Diagnosis', data=data, kind='count', aspect=3, color='green')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
data.hist(color='green')
plt.show()

# %%
X = data[['WBC', 'LYMp', 'NEUTp', 'LYMn', 'NEUTn', 'RBC', 'HGB', 'HCT', 'MCV', 'MCH', 'MCHC', 'PLT', 'PDW', 'PCT']]

# %%
X.shape
# Out:
# (1150, 14)

# %%
Y = data['Diagnosis']
#ya = data_datos["CALIFICACION"] 
Y.shape
# Out:
# (1150,)

# %% [markdown]
# ## CODIFICANDO "Y"

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_codificado = le.fit_transform(Y)

# Mostrar la codificación de cada clase
print("Codificación de clases:")
for i, clase in enumerate(le.classes_):
    print(f"{clase} -> {i}")
# Out:
# Codificación de clases:
# Healthy -> 0
# Iron deficiency anemia -> 1
# Macrocytic anemia -> 2
# Normocytic hypochromic anemia -> 3
# Normocytic normochromic anemia -> 4
# Other microcytic anemia -> 5

# %%
print(le.classes_)
##EN ESE ORDEN ESTAN PARA EL SISTEMA, DE AHI SACA 0 1 2 3 4 5 -->
# Out:
# ['Healthy' 'Iron deficiency anemia' 'Macrocytic anemia'
#  'Normocytic hypochromic anemia' 'Normocytic normochromic anemia'
#  'Other microcytic anemia']

# %%
from sklearn.metrics import roc_curve, auc
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# # PARTICIONAMIENTO DE LA DATA

# %%
from sklearn.model_selection import train_test_split

# Aquí usas X sin cambios y la Y codificada
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y_codificado, test_size=0.2, random_state=0)
print("---")
print(f"Entrenamiento: {X_trainset.shape[0]} muestras, {X_trainset.shape[1]} variables")
print(f"Etiquetas entrenamiento: {y_trainset.shape[0]} valores")
print(f"Prueba: {X_testset.shape[0]} muestras, {X_testset.shape[1]} variables")
print(f"Etiquetas prueba: {y_testset.shape[0]} valores")
# Out:
# ---
# Entrenamiento: 920 muestras, 14 variables
# Etiquetas entrenamiento: 920 valores
# Prueba: 230 muestras, 14 variables
# Etiquetas prueba: 230 valores

# %% [markdown]
# ## BALANCEADO GA

# %%
from imblearn.combine import SMOTETomek
from collections  import Counter

print("Distribución antes del resampling:", Counter(y_trainset))

os_us = SMOTETomek(sampling_strategy='auto', random_state=0)
X_train_res, y_train_res = os_us.fit_resample(X_trainset, y_trainset)

print("Distribución tras aplicar SMOTE-Tomek", Counter(y_train_res))
# Out:
# Distribución antes del resampling: Counter({0: 272, 3: 225, 4: 208, 1: 151, 5: 49, 2: 15})
# Distribución tras aplicar SMOTE-Tomek Counter({5: 271, 2: 271, 1: 266, 4: 262, 0: 260, 3: 256})

# %% [markdown]
# # MODELO LOGISTIC REGRESSION

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# Pipeline con selección de features y modelo
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('selector', SelectKBest(score_func=f_classif, k=20)),  # Selecciona top 20 features
    ('clf', LogisticRegression(max_iter=5000, solver='saga', tol=1e-3))
])

param_grid = {
    'selector__k': [10, 20, 'all'],
    'clf__penalty': ['l1', 'l2', 'elasticnet'],
    'clf__C': np.logspace(-3, 3, 10),
    'clf__class_weight': [None, 'balanced']
}

grid = GridSearchCV(pipe, param_grid, cv=5, scoring='f1_macro', verbose=2)
grid.fit(X_train_res, y_train_res)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.3s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.001, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.004641588833612777, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.004641588833612777, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=10; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.1s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=20; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l1, selector__k=all; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=10; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.1s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.1s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=0.021544346900318832, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# ...
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=l2, selector__k=20; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=None, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.3s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.4s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.4s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.4s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=10; total time=   0.4s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.6s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.6s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.6s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.6s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=20; total time=   0.5s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.5s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.5s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.5s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.5s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l1, selector__k=all; total time=   0.5s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=10; total time=   0.1s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.2s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.3s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.2s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.3s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=20; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=l2, selector__k=all; total time=   0.2s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=10; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=20; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# [CV] END clf__C=1000.0, clf__class_weight=balanced, clf__penalty=elasticnet, selector__k=all; total time=   0.0s
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=20 is greater than n_features=14. All the features will be returned.
#   warnings.warn(
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 300 fits failed out of a total of 900.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 300 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\pipeline.py", line 473, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1204, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Archivos de programa\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.04849061 0.04849061 0.04833582 0.47533256 0.49190485 0.48937654
#         nan        nan        nan 0.04771832 0.04833582 0.0481807
#  0.53388754 0.52449436 0.53284218        nan        nan        nan
#  0.17974117 0.17955374 0.17955374 0.64096868 0.6373839  0.6373839
#         nan        nan        nan 0.16980011 0.17592383 0.17581979
#  0.66043749 0.65458783 0.65458783        nan        nan        nan
#  0.74942751 0.74877644 0.74877644 0.76175132 0.76040739 0.76040739
#         nan        nan        nan 0.75647696 0.75438967 0.75438967
#  0.76916605 0.76180887 0.76117505        nan        nan        nan
#  0.8847433  0.88365308 0.88365308 0.84165747 0.8423432  0.84303217
#         nan        nan        nan 0.88624609 0.88363459 0.88363459
#  0.84026732 0.84392675 0.84321979        nan        nan        nan
#  0.90690896 0.90416486 0.90416486 0.88933714 0.88749965 0.88749965
#         nan        nan        nan 0.90626589 0.90351002 0.90351002
#  0.89000805 0.88688354 0.88688354        nan        nan        nan
#  0.91132931 0.90794349 0.90794349 0.9055369  0.89904962 0.89904962
#         nan        nan        nan 0.91132931 0.90793539 0.90793539
#  0.90296665 0.89727241 0.89727241        nan        nan        nan
#  0.91058507 0.90735523 0.90735523 0.90936842 0.90553336 0.90550132
#         nan        nan        nan 0.91126594 0.90612096 0.90550619
#  0.90934614 0.90557366 0.90557366        nan        nan        nan
#  0.90991085 0.90746187 0.90746187 0.91058507 0.90681501 0.90681501
#         nan        nan        nan 0.91126594 0.90622184 0.90562431
#  0.91003995 0.90562431 0.90562431        nan        nan        nan
#  0.90991085 0.90746187 0.90746187 0.90991085 0.90681501 0.90681501
#         nan        nan        nan 0.91128651 0.90562431 0.90562431
#  0.91065118 0.90562431 0.90562431        nan        nan        nan
#  0.90991085 0.90746187 0.90681501 0.90991085 0.90681501 0.90681501
#         nan        nan        nan 0.91065118 0.90562431 0.90562431
#  0.91128651 0.90562431 0.90562431        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('selector', SelectKBest(k=20)),
#                                        ('clf',
#                                         LogisticRegression(max_iter=5000,
#                                                            solver='saga',
#                                                            tol=0.001))]),
#              param_grid={'clf__C': array([1.00000000e-03, 4.64158883e-03, 2.15443469e-02, 1.00000000e-01,
#        4.64158883e-01, 2.15443469e+00, 1.00000000e+01, 4.64158883e+01,
#        2.15443469e+02, 1.00000000e+03]),
#                          'clf__class_weight': [None, 'balanced'],
#                          'clf__penalty': ['l1', 'l2', 'elasticnet'],
#                          'selector__k': [10, 20, 'all']},
#              scoring='f1_macro', verbose=2)

# %%
print("Mejores parámetros encontrados:", grid.best_params_)
# Out:
# Mejores parámetros encontrados: {'clf__C': 2.154434690031882, 'clf__class_weight': None, 'clf__penalty': 'l1', 'selector__k': 10}

# %%
model = grid.best_estimator_  # Asigna el mejor modelo encontrado por GridSearchCV a la variable 'model'
model  # Muestra el modelo para ver sus parámetros y configuración
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('selector', SelectKBest()),
#                 ('clf',
#                  LogisticRegression(C=2.154434690031882, max_iter=5000,
#                                     penalty='l1', solver='saga', tol=0.001))])

# %%
model.classes_
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
from sklearn.model_selection import KFold, cross_val_score

k_folds = KFold(n_splits=10, shuffle=True, random_state=42)

# Evaluación con datos SIN balancear
scores_unbalanced = cross_val_score(grid.best_estimator_, X_trainset, y_trainset, cv=k_folds)
print("Scores con datos SIN balancear:", scores_unbalanced)
print("Media accuracy SIN balancear:", scores_unbalanced.mean())

# Ajustar el mejor modelo con datos SIN balancear para usar después si quieres ni caso xd
grid.best_estimator_.fit(X_trainset, y_trainset)

# Evaluación con datos BALANCEADOS
scores_balanced = cross_val_score(grid.best_estimator_, X_train_res, y_train_res, cv=k_folds)
print("Scores con datos BALANCEADOS:", scores_balanced)
print("Media accuracy BALANCEADOS:", scores_balanced.mean())

# Ajustar el mejor modelo con datos BALANCEADOS para usar después si quieres
grid.best_estimator_.fit(X_train_res, y_train_res)
##Cada número es la accuracy que obtuvo el modelo en una de las 10 particiones (folds) del KFold con los datos originales, sin aplicar balanceo.
# Out:
# Scores con datos SIN balancear: [0.83695652 0.94565217 0.89130435 0.88043478 0.90217391 0.85869565
#  0.80434783 0.86956522 0.90217391 0.88043478]
# Media accuracy SIN balancear: 0.8771739130434784
# Scores con datos BALANCEADOS: [0.91194969 0.89937107 0.88679245 0.89308176 0.94968553 0.91194969
#  0.91139241 0.85443038 0.94303797 0.94936709]
# Media accuracy BALANCEADOS: 0.911105803678051
# Pipeline(steps=[('scaler', StandardScaler()), ('selector', SelectKBest()),
#                 ('clf',
#                  LogisticRegression(C=2.154434690031882, max_iter=5000,
#                                     penalty='l1', solver='saga', tol=0.001))])

# %% [markdown]
# ## MÉTRICAS DEL MODELO (TRAIN)

# %%
pred = grid.best_estimator_.predict(X_train_res)

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, classification_report, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelBinarizer

probs = grid.predict_proba(X_train_res)

# MÉTRICAS DEL MODELO (TRAIN)
pred = grid.best_estimator_.predict(X_train_res)

print('El accuracy en el conjunto de entrenamiento es:', accuracy_score(y_train_res, pred), '→', accuracy_score(y_train_res, pred)*100, '%')
print('La precisión en el conjunto de entrenamiento es:', precision_score(y_train_res, pred, average='macro'), '→', precision_score(y_train_res, pred, average='macro')*100, '%')
print('La sensibilidad en el conjunto de entrenamiento es:', recall_score(y_train_res, pred, average='macro'), '→', recall_score(y_train_res, pred, average='macro')*100, '%')
print('El F1-score en el conjunto de entrenamiento es:', f1_score(y_train_res, pred, average='macro'), '→', f1_score(y_train_res, pred, average='macro')*100, '%')

roc_auc = roc_auc_score(y_train_res, probs[:, 1]) if len(grid.best_estimator_.classes_) == 2 else roc_auc_score(LabelBinarizer().fit_transform(y_train_res), probs, multi_class='ovr')
print('El ROC AUC en el conjunto de entrenamiento es:', roc_auc, '→', roc_auc*100, '%')

print('Matthews Correlation Coefficient es:', matthews_corrcoef(y_train_res, pred))
# Out:
# El accuracy en el conjunto de entrenamiento es: 0.9243379571248423 → 92.43379571248424 %
# La precisión en el conjunto de entrenamiento es: 0.9252361588126771 → 92.5236158812677 %
# La sensibilidad en el conjunto de entrenamiento es: 0.9234187593888469 → 92.34187593888468 %
# El F1-score en el conjunto de entrenamiento es: 0.9236473630491565 → 92.36473630491565 %
# El ROC AUC en el conjunto de entrenamiento es: 0.9902184755688173 → 99.02184755688172 %
# Matthews Correlation Coefficient es: 0.9094662324920606

# %%
# Solo para mostrar el classification_report con clases decodificadas
y_true_labels = le.inverse_transform(y_train_res)
y_pred_labels = le.inverse_transform(pred)

print(classification_report(y_true_labels, y_pred_labels))
# Out:
#                                 precision    recall  f1-score   support
#
#                        Healthy       0.95      0.87      0.91       260
#         Iron deficiency anemia       0.93      0.92      0.93       266
#              Macrocytic anemia       0.98      1.00      0.99       271
#  Normocytic hypochromic anemia       0.87      0.86      0.87       256
# Normocytic normochromic anemia       0.95      0.93      0.94       262
#        Other microcytic anemia       0.87      0.96      0.91       271
#
#                       accuracy                           0.92      1586
#                      macro avg       0.93      0.92      0.92      1586
#                   weighted avg       0.93      0.92      0.92      1586

# %%
pred = grid.predict(X_trainset)
print(classification_report(le.inverse_transform(y_trainset), le.inverse_transform(pred)))
##decodificado temporalmente xd
# Out:
#                                 precision    recall  f1-score   support
#
#                        Healthy       0.95      0.86      0.90       272
#         Iron deficiency anemia       0.92      0.89      0.91       151
#              Macrocytic anemia       0.75      1.00      0.86        15
#  Normocytic hypochromic anemia       0.85      0.85      0.85       225
# Normocytic normochromic anemia       0.93      0.92      0.92       208
#        Other microcytic anemia       0.58      0.92      0.71        49
#
#                       accuracy                           0.88       920
#                      macro avg       0.83      0.91      0.86       920
#                   weighted avg       0.89      0.88      0.88       920

# %%
# Decodificamos usando tu codificador 'le'
y_true_labels = le.inverse_transform(y_trainset)
y_pred_labels = le.inverse_transform(pred)

# Creamos la matriz de confusión con nombres de clases reales
enf_matrix = pd.crosstab(y_true_labels, y_pred_labels, rownames=['ACTUAL'], colnames=['Predicción'])

# Gráfico
plt.rcParams["figure.figsize"] = (6, 6)
sns.heatmap(enf_matrix, square=True, annot=True, fmt='d', cbar=True)
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Decision Tree Confusion Matrix (Train)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 10
#       8 # Gráfico
#       9 plt.rcParams["figure.figsize"] = (6, 6)
# ---> 10 sns.heatmap(enf_matrix, square=True, annot=True, fmt='d', cbar=True)
#      11 plt.xlabel('Predicted Class')
#      12 plt.ylabel('True Class')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## MÉTRICAS DEL MODELO (TEST)

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, classification_report, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelBinarizer

probs = grid.predict_proba(X_testset)

# MÉTRICAS DEL MODELO (TEST)
pred = grid.best_estimator_.predict(X_testset)

print('El accuracy en el conjunto de prueba es:', accuracy_score(y_testset, pred), '→', accuracy_score(y_testset, pred)*100, '%')
print('La precisión en el conjunto de prueba es:', precision_score(y_testset, pred, average='weighted'), '→', precision_score(y_testset, pred, average='weighted')*100, '%')
print('La sensibilidad en el conjunto de prueba es:', recall_score(y_testset, pred, average='macro'), '→', recall_score(y_testset, pred, average='macro')*100, '%')
print('El F1-score en el conjunto de prueba es:', f1_score(y_testset, pred, average='weighted'), '→', f1_score(y_testset, pred, average='weighted')*100, '%')

roc_auc = roc_auc_score(y_testset, probs[:, 1]) if len(grid.best_estimator_.classes_) == 2 else roc_auc_score(LabelBinarizer().fit_transform(y_testset), probs, multi_class='ovr')
print('El ROC AUC en el conjunto de prueba es:', roc_auc, '→', roc_auc*100, '%')

print('Matthews Correlation Coefficient es:', matthews_corrcoef(y_testset, pred))
# Out:
# El accuracy en el conjunto de prueba es: 0.8739130434782608 → 87.39130434782608 %
# La precisión en el conjunto de prueba es: 0.8996655403877215 → 89.96655403877214 %
# La sensibilidad en el conjunto de prueba es: 0.8975813280925448 → 89.75813280925448 %
# El F1-score en el conjunto de prueba es: 0.8796910637995322 → 87.96910637995322 %
# El ROC AUC en el conjunto de prueba es: 0.9716040523646031 → 97.1604052364603 %
# Matthews Correlation Coefficient es: 0.8407384558209349

# %%
# Decodificamos etiquetas para mostrar nombres reales (temporales)
y_true_labels = le.inverse_transform(y_testset)
y_pred_labels = le.inverse_transform(pred)

from sklearn.metrics import classification_report

print(classification_report(y_true_labels, y_pred_labels))
# Out:
#                                 precision    recall  f1-score   support
#
#                        Healthy       0.67      0.92      0.78        64
#         Iron deficiency anemia       0.84      0.97      0.90        38
#              Macrocytic anemia       0.60      1.00      0.75         3
#  Normocytic hypochromic anemia       0.79      0.50      0.61        54
# Normocytic normochromic anemia       0.82      0.51      0.63        61
#        Other microcytic anemia       0.29      0.60      0.39        10
#
#                       accuracy                           0.71       230
#                      macro avg       0.67      0.75      0.68       230
#                   weighted avg       0.75      0.71      0.70       230

# %%
pred = grid.predict(X_testset)

# Decodificar las etiquetas codificadas a sus nombres originales solo para mostrar
y_test_labels = le.inverse_transform(y_testset)
pred_labels = le.inverse_transform(pred)

# Mostrar el reporte con etiquetas originales
print(classification_report(y_test_labels, pred_labels))
# Out:
#                                 precision    recall  f1-score   support
#
#                        Healthy       0.67      0.92      0.78        64
#         Iron deficiency anemia       0.84      0.97      0.90        38
#              Macrocytic anemia       0.60      1.00      0.75         3
#  Normocytic hypochromic anemia       0.79      0.50      0.61        54
# Normocytic normochromic anemia       0.82      0.51      0.63        61
#        Other microcytic anemia       0.29      0.60      0.39        10
#
#                       accuracy                           0.71       230
#                      macro avg       0.67      0.75      0.68       230
#                   weighted avg       0.75      0.71      0.70       230

# %%
# Decodificar las etiquetas reales y predichas para la matriz
y_test_labels = le.inverse_transform(y_testset)
pred_labels = le.inverse_transform(pred)

# Crear matriz de confusión con etiquetas decodificadas
cnf_matrix = pd.crosstab(y_test_labels, pred_labels, rownames=['ACTUAL'], colnames=['Predicción'])

# Graficar matriz con seaborn
sb.heatmap(cnf_matrix, square=True, annot=True, fmt='d', cbar=True)
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.title('Decision Tree Confusion Matrix (Test)')
plt.rcParams["figure.figsize"] = (6, 6)
plt.show()

# %% [markdown]
# ## ROC CURVE (TRAIN)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt

# Obtener probabilidades para todas las clases usando datos balanceados
probs = model.predict_proba(X_train_res)

# Convertir las etiquetas balanceadas a formato binarizado (para ROC multiclasificación)
lb = LabelBinarizer()
y_train_bin = lb.fit_transform(y_train_res)

# Crear la figura
plt.figure(figsize=(8, 8))

# Iterar sobre cada clase y graficar la curva ROC para esa clase
for i in range(y_train_bin.shape[1]):
    fpr, tpr, _ = roc_curve(y_train_bin[:, i], probs[:, i])
    roc_auc = auc(fpr, tpr)
    clase_decodificada = le.inverse_transform([i])[0]  # Decodifica el índice de la clase
    plt.plot(fpr, tpr, label=f'Clase {clase_decodificada} (AUC = {roc_auc:.2f})')

# Línea de referencia para la aleatoriedad (AUC = 0.5)
plt.plot([0, 1], [0, 1], "k--", label="Chance level (AUC = 0.5)")

# Configuración de los ejes y etiquetas
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Decision Tree ROC Curve (Train Balanceado)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## ROC CURVE (TEST)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt

# Obtener las probabilidades para todas las clases en el conjunto de test
probs = model.predict_proba(X_testset)

# Convertir las etiquetas de test a formato binarizado (para ROC multiclasificación)
lb = LabelBinarizer()
y_test_bin = lb.fit_transform(y_testset)

# Crear la figura
plt.figure(figsize=(8, 8))

# Iterar sobre cada clase y graficar la curva ROC para esa clase
for i in range(y_test_bin.shape[1]):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], probs[:, i])  
    roc_auc = auc(fpr, tpr)
    # Usamos 'le' para decodificar el índice de la clase y mostrar su nombre real
    clase_decodificada = le.inverse_transform([i])[0]
    plt.plot(fpr, tpr, label=f'Clase {clase_decodificada} (AUC = {roc_auc:.2f})')

# Línea de referencia para la aleatoriedad (AUC = 0.5)
plt.plot([0, 1], [0, 1], "k--", label="Chance level (AUC = 0.5)")

# Configuración de los ejes y etiquetas
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Decision Tree ROC Curve (Test)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## PRECISION RECALL CURVE (TRAIN)

# %%
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer

# Convertir las etiquetas balanceadas a formato binarizado
lb = LabelBinarizer()
y_train_bin = lb.fit_transform(y_train_res)

# Obtener probabilidades para todas las clases (datos balanceados)
probs = model.predict_proba(X_train_res)

plt.figure(figsize=(8, 8))

for i in range(y_train_bin.shape[1]):
    lr_precision, lr_recall, _ = precision_recall_curve(y_train_bin[:, i], probs[:, i])
    roc_auc = auc(lr_recall, lr_precision)
    # Decodificamos la clase para mostrar nombre original
    clase_decodificada = le.inverse_transform([i])[0]
    plt.plot(lr_recall, lr_precision, marker='.', label=f'Clase {clase_decodificada} (AUC = {roc_auc:.2f})')

# Línea de referencia para la aleatoriedad según datos balanceados
no_skill = len(y_train_res[y_train_res==1]) / len(y_train_res)
plt.plot([0, 1], [no_skill, no_skill], 'k--', lw=2)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Decision Tree Precision Recall (Train Balanceado)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## PRECISION RECALL CURVE (TEST)

# %%
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer

# Convertir las etiquetas a formato binarizado
lb = LabelBinarizer()
y_test_bin = lb.fit_transform(y_testset)

# Obtener probabilidades para todas las clases
probs = model.predict_proba(X_testset)

# Crear la figura
plt.figure(figsize=(8, 8))

# Iterar sobre cada clase y graficar la curva Precision-Recall para esa clase
for i in range(y_test_bin.shape[1]):
    lr_precision, lr_recall, _ = precision_recall_curve(y_test_bin[:, i], probs[:, i])
    roc_auc = auc(lr_recall, lr_precision)
    # Decodificación temporal para mostrar nombres originales
    clase_decodificada = le.inverse_transform([i])[0]
    plt.plot(lr_recall, lr_precision, marker='.', label=f'Clase {clase_decodificada} (AUC = {roc_auc:.2f})')

# Línea de referencia para la aleatoriedad
no_skill = len(y_testset[y_testset==1]) / len(y_testset)
plt.plot([0, 1], [no_skill, no_skill], 'k--', lw=2)

# Etiquetas de los ejes
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Decision Tree Precision Recall (Test)')

# Mostrar leyenda
plt.legend(loc='best')

# Mostrar la gráfica
plt.show()

# %%
import pickle
pickle.dump(model, open('./Models/rl_hp.pkl', 'wb'))
