# %%
# !pip install pytorch-tabnet
import pandas as pd

data = pd.read_csv("AnemiaTipos.csv", index_col=None)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef
import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: pytorch-tabnet in d:\archivos de programa\anaconda\lib\site-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in d:\archivos de programa\anaconda\lib\site-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in d:\archivos de programa\anaconda\lib\site-packages (from pytorch-tabnet) (1.5.1)
# Requirement already satisfied: scipy>1.4 in d:\archivos de programa\anaconda\lib\site-packages (from pytorch-tabnet) (1.13.1)
# Requirement already satisfied: torch>=1.3 in d:\archivos de programa\anaconda\lib\site-packages (from pytorch-tabnet) (2.7.0)
# Requirement already satisfied: tqdm>=4.36 in d:\archivos de programa\anaconda\lib\site-packages (from pytorch-tabnet) (4.66.4)
# Requirement already satisfied: joblib>=1.2.0 in d:\archivos de programa\anaconda\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\archivos de programa\anaconda\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in d:\archivos de programa\anaconda\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\archivos de programa\anaconda\lib\site-packages (from torch>=1.3->pytorch-tabnet) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\archivos de programa\anaconda\lib\site-packages (from torch>=1.3->pytorch-tabnet) (1.14.0)
# Requirement already satisfied: networkx in d:\archivos de programa\anaconda\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.2.1)
# Requirement already satisfied: jinja2 in d:\archivos de programa\anaconda\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in d:\archivos de programa\anaconda\lib\site-packages (from torch>=1.3->pytorch-tabnet) (2024.3.1)
# Requirement already satisfied: setuptools in d:\archivos de programa\anaconda\lib\site-packages (from torch>=1.3->pytorch-tabnet) (69.5.1)
# Requirement already satisfied: colorama in d:\archivos de programa\anaconda\lib\site-packages (from tqdm>=4.36->pytorch-tabnet) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\archivos de programa\anaconda\lib\site-packages (from sympy>=1.13.3->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\archivos de programa\anaconda\lib\site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.3)

# %%
data
# Out:
#         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB       HCT   MCV  \
# 0     10.00  43.200  50.100  4.30000  5.00000  2.77   7.3   24.2000  87.7
# 1     10.00  42.400  52.300  4.20000  5.30000  2.84   7.3   25.0000  88.2
# 2      7.20  30.700  60.700  2.20000  4.40000  3.97   9.0   30.5000  77.0
# 3      6.00  30.200  63.500  1.80000  3.80000  4.22   3.8   32.8000  77.9
# 4      4.20  39.100  53.700  1.60000  2.30000  3.93   0.4  316.0000  80.6
# ...     ...     ...     ...      ...      ...   ...   ...       ...   ...
# 1145   4.40  25.845  77.511  1.88076  5.14094  4.86  13.5   46.1526  80.7
# 1146   5.60  25.845  77.511  1.88076  5.14094  4.85  15.0   46.1526  91.7
# 1147   9.20  25.845  77.511  1.88076  5.14094  4.47  13.1   46.1526  88.7
# 1148   6.48  25.845  77.511  1.88076  5.14094  4.75  13.2   46.1526  86.7
# 1149   8.80  25.845  77.511  1.88076  5.14094  4.95  15.2   46.1526  89.7
#
#        MCH  MCHC    PLT        PDW      PCT                      Diagnosis
# 0     26.3  30.1  189.0  12.500000  0.17000  Normocytic hypochromic anemia
# 1     25.7  20.2  180.0  12.500000  0.16000  Normocytic hypochromic anemia
# 2     22.6  29.5  148.0  14.300000  0.14000         Iron deficiency anemia
# 3     23.2  29.8  143.0  11.300000  0.12000         Iron deficiency anemia
# 4     23.9  29.7  236.0  12.800000  0.22000  Normocytic hypochromic anemia
# ...    ...   ...    ...        ...      ...                            ...
# 1145  27.7  34.4  180.0  14.312512  0.26028                        Healthy
# 1146  31.0  33.8  215.0  14.312512  0.26028                        Healthy
# 1147  29.3  33.0  329.0  14.312512  0.26028                        Healthy
# 1148  27.9  32.1  174.0  14.312512  0.26028                        Healthy
# 1149  30.6  34.2  279.0  14.312512  0.26028                        Healthy
#
# [1150 rows x 15 columns]

# %%
data.isnull().any()
# Out:
# WBC          False
# LYMp         False
# NEUTp        False
# LYMn         False
# NEUTn        False
# RBC          False
# HGB          False
# HCT          False
# MCV          False
# MCH          False
# MCHC         False
# PLT          False
# PDW          False
# PCT          False
# Diagnosis    False
# dtype: bool

# %%
X = data[['WBC', 'LYMp', 'NEUTp', 'LYMn', 'NEUTn', 'RBC', 'HGB', 'HCT', 'MCV', 'MCH', 'MCHC', 'PLT', 'PDW', 'PCT']]

# %%
X.shape
# Out:
# (1150, 14)

# %%
Y = data['Diagnosis']
#ya = data_datos["CALIFICACION_2"]
Y.shape
# Out:
# (1150,)

# %% [markdown]
# ## CODIFICANDO "Y"

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_codificado = le.fit_transform(Y)

# Mostrar la codificación de cada clase
print("Codificación de clases:")
for i, clase in enumerate(le.classes_):
    print(f"{clase} -> {i}")
# Out:
# Codificación de clases:
# Healthy -> 0
# Iron deficiency anemia -> 1
# Macrocytic anemia -> 2
# Normocytic hypochromic anemia -> 3
# Normocytic normochromic anemia -> 4
# Other microcytic anemia -> 5

# %%
print(le.classes_)
##EN ESE ORDEN ESTAN PARA EL SISTEMA, DE AHI SACA 0 1 2 3 4 5 -->
# Out:
# ['Healthy' 'Iron deficiency anemia' 'Macrocytic anemia'
#  'Normocytic hypochromic anemia' 'Normocytic normochromic anemia'
#  'Other microcytic anemia']

# %%
from sklearn.metrics import roc_curve, auc
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# # PARTICIONAMIENTO DE LA DATA

# %%
from sklearn.model_selection import train_test_split

# Aquí usas X sin cambios y la Y codificada
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y_codificado, test_size=0.2, random_state=0)
print("---")
print(f"Entrenamiento: {X_trainset.shape[0]} muestras, {X_trainset.shape[1]} variables")
print(f"Etiquetas entrenamiento: {y_trainset.shape[0]} valores")
print(f"Prueba: {X_testset.shape[0]} muestras, {X_testset.shape[1]} variables")
print(f"Etiquetas prueba: {y_testset.shape[0]} valores")
# Out:
# ---
# Entrenamiento: 920 muestras, 14 variables
# Etiquetas entrenamiento: 920 valores
# Prueba: 230 muestras, 14 variables
# Etiquetas prueba: 230 valores

# %% [markdown]
# # BALANCEO DE DATA

# %%
from imblearn.combine import SMOTETomek
from collections  import Counter

print("Distribución antes del resampling:", Counter(y_trainset))

os_us = SMOTETomek(sampling_strategy='auto', random_state=0)
X_train_res, y_train_res = os_us.fit_resample(X_trainset, y_trainset)

print("Distribución tras aplicar SMOTE-Tomek", Counter(y_train_res))
# Out:
# Distribución antes del resampling: Counter({0: 272, 3: 225, 4: 208, 1: 151, 5: 49, 2: 15})
# Distribución tras aplicar SMOTE-Tomek Counter({5: 271, 2: 271, 1: 266, 4: 262, 0: 260, 3: 256})

# %%
from sklearn.preprocessing import StandardScaler
X_train_res, y_train_res = os_us.fit_resample(X_train, y_train)

# Ahora escalar los datos balanceados
scaler = StandardScaler()
X_train_res_scaled = scaler.fit_tra nsform(X_train_res)
X_test_scaled = scaler.transform(X_test)  # Escalar test con mismo scaler

# Convertir a DataFrame si lo necesitas
X_train_res_df = pd.DataFrame(X_train_res_scaled, columns=X.columns)
y_train_res_df = pd.Series(y_train_res, name='Diagnosis')
train_df_res = pd.concat([X_train_res_df, y_train_res_df], axis=1)

# %% [markdown]
# # MODELO TabNET

# %%
# !pip install skorch
# Out:
# Collecting skorch
#   Downloading skorch-1.1.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.3 in d:\archivos de programa\anaconda\lib\site-packages (from skorch) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in d:\archivos de programa\anaconda\lib\site-packages (from skorch) (1.5.1)
# Requirement already satisfied: scipy>=1.1.0 in d:\archivos de programa\anaconda\lib\site-packages (from skorch) (1.13.1)
# Requirement already satisfied: tabulate>=0.7.7 in d:\archivos de programa\anaconda\lib\site-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in d:\archivos de programa\anaconda\lib\site-packages (from skorch) (4.66.4)
# Requirement already satisfied: joblib>=1.2.0 in d:\archivos de programa\anaconda\lib\site-packages (from scikit-learn>=0.22.0->skorch) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\archivos de programa\anaconda\lib\site-packages (from scikit-learn>=0.22.0->skorch) (3.5.0)
# Requirement already satisfied: colorama in d:\archivos de programa\anaconda\lib\site-packages (from tqdm>=4.14.0->skorch) (0.4.6)
# Downloading skorch-1.1.0-py3-none-any.whl (228 kB)
#    ---------------------------------------- 0.0/228.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/228.9 kB ? eta -:--:--
#    --------------------- ------------------ 122.9/228.9 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  225.3/228.9 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 228.9/228.9 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: skorch
# Successfully installed skorch-1.1.0

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelBinarizer
import numpy as np

# Escalar y codificar previamente
# X_train_res_scaled, y_train_encoded, X_test_scaled, y_test_encoded

# Definimos el grid de hiperparámetros
param_grid = {
    'n_d': [16, 24],
    'n_a': [16, 24],
    'n_steps': [5, 7],
    'gamma': [1.3, 1.5],
    'lambda_sparse': [1e-5, 1e-4],
    'lr': [1e-3, 2e-3]
}

from itertools import product

# Generar todas las combinaciones posibles
keys, values = zip(*param_grid.items())
combinations = [dict(zip(keys, v)) for v in product(*values)]

best_score = 0
best_model = None
best_params = None

print(f"Probando {len(combinations)} combinaciones de hiperparámetros...\n")

for i, params in enumerate(combinations):
    print(f"Probando combinación {i+1}: {params}")
    
    model = TabNetClassifier(
        n_d=params['n_d'],
        n_a=params['n_a'],
        n_steps=params['n_steps'],
        gamma=params['gamma'],
        lambda_sparse=params['lambda_sparse'],
        optimizer_params=dict(lr=params['lr']),
        scheduler_params={"step_size": 10, "gamma": 0.9},
        mask_type='sparsemax',
        momentum=0.3,
        verbose=0
    )

    model.fit(
        X_train=X_train_res_scaled, y_train=y_train_encoded,
        eval_set=[(X_test_scaled, y_test_encoded)],
        eval_metric=['accuracy'],
        max_epochs=150,
        patience=20,
        batch_size=512,
        virtual_batch_size=64
    )

    # Evaluar en test
    y_pred = model.predict(X_test_scaled)
    acc = accuracy_score(y_test_encoded, y_pred)
    print(f"→ Accuracy: {acc:.4f}")

    if acc > best_score:
        best_score = acc
        best_model = model
        best_params = params

print("\n✅ Mejor combinación encontrada:")
print(best_params)
print(f"→ Accuracy: {best_score:.4f}")
# Out:
# Probando 64 combinaciones de hiperparámetros...
#
# Probando combinación 1: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 56 with best_epoch = 36 and best_val_0_accuracy = 0.59565
# → Accuracy: 0.5957
# Probando combinación 2: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 110 with best_epoch = 90 and best_val_0_accuracy = 0.78261
# → Accuracy: 0.7826
# Probando combinación 3: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 52 with best_epoch = 32 and best_val_0_accuracy = 0.5913
# → Accuracy: 0.5913
# Probando combinación 4: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 114 with best_epoch = 94 and best_val_0_accuracy = 0.73478
# → Accuracy: 0.7348
# Probando combinación 5: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 56 with best_epoch = 36 and best_val_0_accuracy = 0.59565
# → Accuracy: 0.5957
# Probando combinación 6: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 114 with best_epoch = 94 and best_val_0_accuracy = 0.7913
# → Accuracy: 0.7913
# Probando combinación 7: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 115 with best_epoch = 95 and best_val_0_accuracy = 0.68261
# → Accuracy: 0.6826
# Probando combinación 8: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 147 and best_val_0_accuracy = 0.83913
# → Accuracy: 0.8391
# Probando combinación 9: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 58 with best_epoch = 38 and best_val_0_accuracy = 0.54348
# → Accuracy: 0.5435
# Probando combinación 10: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 104 with best_epoch = 84 and best_val_0_accuracy = 0.69565
# → Accuracy: 0.6957
# Probando combinación 11: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 113 with best_epoch = 93 and best_val_0_accuracy = 0.65217
# → Accuracy: 0.6522
# Probando combinación 12: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 138 and best_val_0_accuracy = 0.78261
# → Accuracy: 0.7826
# Probando combinación 13: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 83 with best_epoch = 63 and best_val_0_accuracy = 0.56957
# → Accuracy: 0.5696
# Probando combinación 14: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 138 with best_epoch = 118 and best_val_0_accuracy = 0.76522
# → Accuracy: 0.7652
# Probando combinación 15: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 53 with best_epoch = 33 and best_val_0_accuracy = 0.50435
# → Accuracy: 0.5043
# Probando combinación 16: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 95 with best_epoch = 75 and best_val_0_accuracy = 0.70435
# → Accuracy: 0.7043
# Probando combinación 17: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 22 with best_epoch = 2 and best_val_0_accuracy = 0.16522
# → Accuracy: 0.1652
# Probando combinación 18: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 131 and best_val_0_accuracy = 0.77826
# → Accuracy: 0.7783
# Probando combinación 19: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 107 with best_epoch = 87 and best_val_0_accuracy = 0.64348
# → Accuracy: 0.6435
# Probando combinación 20: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 142 with best_epoch = 122 and best_val_0_accuracy = 0.73913
# → Accuracy: 0.7391
# Probando combinación 21: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 132 with best_epoch = 112 and best_val_0_accuracy = 0.63913
# → Accuracy: 0.6391
# Probando combinación 22: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 91 with best_epoch = 71 and best_val_0_accuracy = 0.6913
# → Accuracy: 0.6913
# Probando combinación 23: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 89 with best_epoch = 69 and best_val_0_accuracy = 0.5913
# → Accuracy: 0.5913
# Probando combinación 24: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 79 with best_epoch = 59 and best_val_0_accuracy = 0.61739
# → Accuracy: 0.6174
# Probando combinación 25: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 139 with best_epoch = 119 and best_val_0_accuracy = 0.61304
# → Accuracy: 0.6130
# Probando combinación 26: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 132 with best_epoch = 112 and best_val_0_accuracy = 0.71304
# → Accuracy: 0.7130
# Probando combinación 27: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 142 with best_epoch = 122 and best_val_0_accuracy = 0.65652
# → Accuracy: 0.6565
# Probando combinación 28: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 139 and best_val_0_accuracy = 0.83913
# → Accuracy: 0.8391
# Probando combinación 29: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 68 with best_epoch = 48 and best_val_0_accuracy = 0.43913
# → Accuracy: 0.4391
# Probando combinación 30: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 107 with best_epoch = 87 and best_val_0_accuracy = 0.64783
# → Accuracy: 0.6478
# Probando combinación 31: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 142 with best_epoch = 122 and best_val_0_accuracy = 0.65652
# → Accuracy: 0.6565
# Probando combinación 32: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 123 with best_epoch = 103 and best_val_0_accuracy = 0.66957
# → Accuracy: 0.6696
# Probando combinación 33: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 119 with best_epoch = 99 and best_val_0_accuracy = 0.7087
# → Accuracy: 0.7087
# Probando combinación 34: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 97 with best_epoch = 77 and best_val_0_accuracy = 0.77826
# → Accuracy: 0.7783
# Probando combinación 35: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 125 with best_epoch = 105 and best_val_0_accuracy = 0.6913
# → Accuracy: 0.6913
# Probando combinación 36: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 125 with best_epoch = 105 and best_val_0_accuracy = 0.81304
# → Accuracy: 0.8130
# Probando combinación 37: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
# Stop training because you reached max_epochs = 150 with best_epoch = 142 and best_val_0_accuracy = 0.72609
# → Accuracy: 0.7261
# Probando combinación 38: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 93 with best_epoch = 73 and best_val_0_accuracy = 0.7087
# → Accuracy: 0.7087
# Probando combinación 39: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 84 with best_epoch = 64 and best_val_0_accuracy = 0.64783
# → Accuracy: 0.6478
# Probando combinación 40: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 57 with best_epoch = 37 and best_val_0_accuracy = 0.64348
# → Accuracy: 0.6435
# Probando combinación 41: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 138 with best_epoch = 118 and best_val_0_accuracy = 0.73913
# → Accuracy: 0.7391
# Probando combinación 42: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 108 with best_epoch = 88 and best_val_0_accuracy = 0.72609
# → Accuracy: 0.7261
# Probando combinación 43: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 77 with best_epoch = 57 and best_val_0_accuracy = 0.5
# → Accuracy: 0.5000
# Probando combinación 44: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 78 with best_epoch = 58 and best_val_0_accuracy = 0.67391
# → Accuracy: 0.6739
# Probando combinación 45: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 120 with best_epoch = 100 and best_val_0_accuracy = 0.62609
# → Accuracy: 0.6261
# Probando combinación 46: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 50 with best_epoch = 30 and best_val_0_accuracy = 0.46522
# → Accuracy: 0.4652
# Probando combinación 47: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
# Stop training because you reached max_epochs = 150 with best_epoch = 142 and best_val_0_accuracy = 0.67826
# → Accuracy: 0.6783
# Probando combinación 48: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 145 with best_epoch = 125 and best_val_0_accuracy = 0.7913
# → Accuracy: 0.7913
# Probando combinación 49: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 121 with best_epoch = 101 and best_val_0_accuracy = 0.73913
# → Accuracy: 0.7391
# Probando combinación 50: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 107 with best_epoch = 87 and best_val_0_accuracy = 0.8087
# → Accuracy: 0.8087
# Probando combinación 51: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
# Stop training because you reached max_epochs = 150 with best_epoch = 137 and best_val_0_accuracy = 0.81304
# → Accuracy: 0.8130
# Probando combinación 52: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 131 with best_epoch = 111 and best_val_0_accuracy = 0.83478
# → Accuracy: 0.8348
# Probando combinación 53: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 65 with best_epoch = 45 and best_val_0_accuracy = 0.56087
# → Accuracy: 0.5609
# Probando combinación 54: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 100 with best_epoch = 80 and best_val_0_accuracy = 0.78696
# → Accuracy: 0.7870
# Probando combinación 55: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 53 with best_epoch = 33 and best_val_0_accuracy = 0.52174
# → Accuracy: 0.5217
# Probando combinación 56: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 149 and best_val_0_accuracy = 0.86522
# → Accuracy: 0.8652
# Probando combinación 57: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 109 with best_epoch = 89 and best_val_0_accuracy = 0.73478
# → Accuracy: 0.7348
# Probando combinación 58: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 59 with best_epoch = 39 and best_val_0_accuracy = 0.67391
# → Accuracy: 0.6739
# Probando combinación 59: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 121 with best_epoch = 101 and best_val_0_accuracy = 0.71304
# → Accuracy: 0.7130
# Probando combinación 60: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 148 with best_epoch = 128 and best_val_0_accuracy = 0.84348
# → Accuracy: 0.8435
# Probando combinación 61: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 103 with best_epoch = 83 and best_val_0_accuracy = 0.66087
# → Accuracy: 0.6609
# Probando combinación 62: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 119 with best_epoch = 99 and best_val_0_accuracy = 0.76522
# → Accuracy: 0.7652
# Probando combinación 63: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 148 with best_epoch = 128 and best_val_0_accuracy = 0.71304
# → Accuracy: 0.7130
# Probando combinación 64: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 117 with best_epoch = 97 and best_val_0_accuracy = 0.70435
# → Accuracy: 0.7043
#
# ✅ Mejor combinación encontrada:
# {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
# → Accuracy: 0.8652

# %% [markdown]
# ## MÉTRICAS DEL MODELO TRAIN

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelBinarizer
import numpy as np

# Evaluar el mejor modelo sobre el conjunto de entrenamiento
train_pred = best_model.predict(X_train_res_scaled)
train_probs = best_model.predict_proba(X_train_res_scaled)

print("\n--- MÉTRICAS EN EL CONJUNTO DE ENTRENAMIENTO ---")
print('Accuracy:', accuracy_score(y_train_encoded, train_pred), '→', accuracy_score(y_train_encoded, train_pred)*100, '%')
print('Precisión:', precision_score(y_train_encoded, train_pred, average='macro'), '→', precision_score(y_train_encoded, train_pred, average='macro')*100, '%')
print('Recall (sensibilidad):', recall_score(y_train_encoded, train_pred, average='macro'), '→', recall_score(y_train_encoded, train_pred, average='macro')*100, '%')
print('F1-score:', f1_score(y_train_encoded, train_pred, average='macro'), '→', f1_score(y_train_encoded, train_pred, average='macro')*100, '%')

# AUC (manejo multiclase o binario)
if len(np.unique(y_train_encoded)) == 2:
    roc_auc = roc_auc_score(y_train_encoded, train_probs[:, 1])
else:
    roc_auc = roc_auc_score(LabelBinarizer().fit_transform(y_train_encoded), train_probs, multi_class='ovr')
print('ROC AUC:', roc_auc, '→', roc_auc*100, '%')

# MCC
print('Matthews Correlation Coefficient:', matthews_corrcoef(y_train_encoded, train_pred))
# Out:
# --- MÉTRICAS EN EL CONJUNTO DE ENTRENAMIENTO ---
# Accuracy: 0.9041614123581336 → 90.41614123581337 %
# Precisión: 0.9071355341552755 → 90.71355341552754 %
# Recall (sensibilidad): 0.9033686027884301 → 90.336860278843 %
# F1-score: 0.9034643987629654 → 90.34643987629653 %
# ROC AUC: 0.9858092408339187 → 98.58092408339188 %
# Matthews Correlation Coefficient: 0.8856710886211255

# %% [markdown]
# ## MÉTRICAS DEL MODELO TEST

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, classification_report, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelBinarizer

# Predicciones y probabilidades sobre el conjunto de prueba
test_pred = best_model.predict(X_test_scaled)
test_probs = best_model.predict_proba(X_test_scaled)

print("\n--- MÉTRICAS EN EL CONJUNTO DE PRUEBA ---")

print('Accuracy:', accuracy_score(y_test_encoded, test_pred), '→', accuracy_score(y_test_encoded, test_pred)*100, '%')
print('Precisión:', precision_score(y_test_encoded, test_pred, average='weighted'), '→', precision_score(y_test_encoded, test_pred, average='weighted')*100, '%')
print('Recall (sensibilidad):', recall_score(y_test_encoded, test_pred, average='macro'), '→', recall_score(y_test_encoded, test_pred, average='macro')*100, '%')
print('F1-score:', f1_score(y_test_encoded, test_pred, average='weighted'), '→', f1_score(y_test_encoded, test_pred, average='weighted')*100, '%')

# AUC
if len(np.unique(y_test_encoded)) == 2:
    roc_auc = roc_auc_score(y_test_encoded, test_probs[:, 1])
else:
    roc_auc = roc_auc_score(LabelBinarizer().fit_transform(y_test_encoded), test_probs, multi_class='ovr')
print('ROC AUC:', roc_auc, '→', roc_auc*100, '%')

# MCC
print('Matthews Correlation Coefficient:', matthews_corrcoef(y_test_encoded, test_pred), '→', matthews_corrcoef(y_test_encoded, test_pred)*100, '%')

# Reporte de clasificación
print("\nClassification Report (TEST):")
print(classification_report(y_test_encoded, test_pred, target_names=label_encoder.classes_.astype(str)))
# Out:
# --- MÉTRICAS EN EL CONJUNTO DE PRUEBA ---
# Accuracy: 0.8652173913043478 → 86.52173913043478 %
# Precisión: 0.8816461443463731 → 88.16461443463731 %
# Recall (sensibilidad): 0.906198487547801 → 90.6198487547801 %
# F1-score: 0.868940143996996 → 86.8940143996996 %
# ROC AUC: 0.9749053551608897 → 97.49053551608897 %
# Matthews Correlation Coefficient: 0.8277895240567741 → 82.77895240567742 %
#
# Classification Report (TEST):
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88        64
#            1       0.97      0.89      0.93        38
#            2       0.60      1.00      0.75         3
#            3       0.80      0.80      0.80        54
#            4       0.92      0.92      0.92        61
#            5       0.56      1.00      0.71        10
#
#     accuracy                           0.87       230
#    macro avg       0.80      0.91      0.83       230
# weighted avg       0.88      0.87      0.87       230
