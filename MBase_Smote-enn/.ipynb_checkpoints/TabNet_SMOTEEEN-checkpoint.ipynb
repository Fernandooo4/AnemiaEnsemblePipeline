# %%
# !pip install pytorch-tabnet
import pandas as pd

data = pd.read_csv("AnemiaTipos.csv", index_col=None)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef
import warnings
warnings.filterwarnings("ignore")
# Out:
# Collecting pytorch-tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\luisc\anaconda3\lib\site-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in c:\users\luisc\anaconda3\lib\site-packages (from pytorch-tabnet) (1.5.1)
# Requirement already satisfied: scipy>1.4 in c:\users\luisc\anaconda3\lib\site-packages (from pytorch-tabnet) (1.13.1)
# Requirement already satisfied: torch>=1.3 in c:\users\luisc\anaconda3\lib\site-packages (from pytorch-tabnet) (2.7.1)
# Requirement already satisfied: tqdm>=4.36 in c:\users\luisc\anaconda3\lib\site-packages (from pytorch-tabnet) (4.66.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\luisc\anaconda3\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\luisc\anaconda3\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in c:\users\luisc\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\luisc\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\luisc\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (1.14.0)
# Requirement already satisfied: networkx in c:\users\luisc\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.3)
# Requirement already satisfied: jinja2 in c:\users\luisc\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\luisc\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\luisc\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (75.1.0)
# Requirement already satisfied: colorama in c:\users\luisc\anaconda3\lib\site-packages (from tqdm>=4.36->pytorch-tabnet) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\luisc\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luisc\anaconda3\lib\site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.3)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
# Installing collected packages: pytorch-tabnet
# Successfully installed pytorch-tabnet-4.1.0

# %%
data
# Out:
#         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB       HCT   MCV  \
# 0     10.00  43.200  50.100  4.30000  5.00000  2.77   7.3   24.2000  87.7
# 1     10.00  42.400  52.300  4.20000  5.30000  2.84   7.3   25.0000  88.2
# 2      7.20  30.700  60.700  2.20000  4.40000  3.97   9.0   30.5000  77.0
# 3      6.00  30.200  63.500  1.80000  3.80000  4.22   3.8   32.8000  77.9
# 4      4.20  39.100  53.700  1.60000  2.30000  3.93   0.4  316.0000  80.6
# ...     ...     ...     ...      ...      ...   ...   ...       ...   ...
# 1145   4.40  25.845  77.511  1.88076  5.14094  4.86  13.5   46.1526  80.7
# 1146   5.60  25.845  77.511  1.88076  5.14094  4.85  15.0   46.1526  91.7
# 1147   9.20  25.845  77.511  1.88076  5.14094  4.47  13.1   46.1526  88.7
# 1148   6.48  25.845  77.511  1.88076  5.14094  4.75  13.2   46.1526  86.7
# 1149   8.80  25.845  77.511  1.88076  5.14094  4.95  15.2   46.1526  89.7
#
#        MCH  MCHC    PLT        PDW      PCT                      Diagnosis
# 0     26.3  30.1  189.0  12.500000  0.17000  Normocytic hypochromic anemia
# 1     25.7  20.2  180.0  12.500000  0.16000  Normocytic hypochromic anemia
# 2     22.6  29.5  148.0  14.300000  0.14000         Iron deficiency anemia
# 3     23.2  29.8  143.0  11.300000  0.12000         Iron deficiency anemia
# 4     23.9  29.7  236.0  12.800000  0.22000  Normocytic hypochromic anemia
# ...    ...   ...    ...        ...      ...                            ...
# 1145  27.7  34.4  180.0  14.312512  0.26028                        Healthy
# 1146  31.0  33.8  215.0  14.312512  0.26028                        Healthy
# 1147  29.3  33.0  329.0  14.312512  0.26028                        Healthy
# 1148  27.9  32.1  174.0  14.312512  0.26028                        Healthy
# 1149  30.6  34.2  279.0  14.312512  0.26028                        Healthy
#
# [1150 rows x 15 columns]

# %%
data.isnull().any()
# Out:
# WBC          False
# LYMp         False
# NEUTp        False
# LYMn         False
# NEUTn        False
# RBC          False
# HGB          False
# HCT          False
# MCV          False
# MCH          False
# MCHC         False
# PLT          False
# PDW          False
# PCT          False
# Diagnosis    False
# dtype: bool

# %%
X = data[['WBC', 'LYMp', 'NEUTp', 'LYMn', 'NEUTn', 'RBC', 'HGB', 'HCT', 'MCV', 'MCH', 'MCHC', 'PLT', 'PDW', 'PCT']]

# %%
X.shape
# Out:
# (1150, 14)

# %%
Y = data['Diagnosis']
#ya = data_datos["CALIFICACION_2"]
Y.shape
# Out:
# (1150,)

# %% [markdown]
# ## CODIFICANDO "Y"

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_codificado = le.fit_transform(Y)

# Mostrar la codificación de cada clase
print("Codificación de clases:")
for i, clase in enumerate(le.classes_):
    print(f"{clase} -> {i}")
# Out:
# Codificación de clases:
# Healthy -> 0
# Iron deficiency anemia -> 1
# Macrocytic anemia -> 2
# Normocytic hypochromic anemia -> 3
# Normocytic normochromic anemia -> 4
# Other microcytic anemia -> 5

# %%
print(le.classes_)
##EN ESE ORDEN ESTAN PARA EL SISTEMA, DE AHI SACA 0 1 2 3 4 5 -->
# Out:
# ['Healthy' 'Iron deficiency anemia' 'Macrocytic anemia'
#  'Normocytic hypochromic anemia' 'Normocytic normochromic anemia'
#  'Other microcytic anemia']

# %%
from sklearn.metrics import roc_curve, auc
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# # PARTICIONAMIENTO DE LA DATA

# %%
from sklearn.model_selection import train_test_split

# Aquí usas X sin cambios y la Y codificada
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y_codificado, test_size=0.2, random_state=0)
print("---")
print(f"Entrenamiento: {X_trainset.shape[0]} muestras, {X_trainset.shape[1]} variables")
print(f"Etiquetas entrenamiento: {y_trainset.shape[0]} valores")
print(f"Prueba: {X_testset.shape[0]} muestras, {X_testset.shape[1]} variables")
print(f"Etiquetas prueba: {y_testset.shape[0]} valores")
# Out:
# ---
# Entrenamiento: 920 muestras, 14 variables
# Etiquetas entrenamiento: 920 valores
# Prueba: 230 muestras, 14 variables
# Etiquetas prueba: 230 valores

# %% [markdown]
# # BALANCEO DE DATA

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

print("Distribución antes del resampling:", Counter(y_trainset))

smote = SMOTE(sampling_strategy='auto', random_state=0)
X_train_res, y_train_res = smote.fit_resample(X_trainset, y_trainset)

print("Distribución tras aplicar SMOTE:", Counter(y_train_res))
# Out:
# Distribución antes del resampling: Counter({0: 272, 3: 225, 4: 208, 1: 151, 5: 49, 2: 15})
# Distribución tras aplicar SMOTE: Counter({0: 272, 1: 272, 3: 272, 4: 272, 5: 272, 2: 272})

# %%
from sklearn.preprocessing import StandardScaler

# Escalar los datos balanceados
scaler = StandardScaler()
X_train_res_scaled = scaler.fit_transform(X_train_res)
X_test_scaled = scaler.transform(X_testset)  # Ojo: debe ser el mismo set que usas en el split

# Convertir a DataFrame (opcional)
X_train_res_df = pd.DataFrame(X_train_res_scaled, columns=X.columns)
y_train_res_df = pd.Series(y_train_res, name='Diagnosis')
train_df_res = pd.concat([X_train_res_df, y_train_res_df], axis=1)

# %% [markdown]
# # MODELO TabNET

# %%
# !pip install skorch
# Out:
# Requirement already satisfied: skorch in c:\users\luisc\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\luisc\anaconda3\lib\site-packages (from skorch) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\luisc\anaconda3\lib\site-packages (from skorch) (1.5.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\luisc\anaconda3\lib\site-packages (from skorch) (1.13.1)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\luisc\anaconda3\lib\site-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in c:\users\luisc\anaconda3\lib\site-packages (from skorch) (4.66.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\luisc\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\luisc\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (3.5.0)
# Requirement already satisfied: colorama in c:\users\luisc\anaconda3\lib\site-packages (from tqdm>=4.14.0->skorch) (0.4.6)

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import accuracy_score
import numpy as np
from itertools import product

# Definimos el grid de hiperparámetros
param_grid = {
    'n_d': [16, 24],
    'n_a': [16, 24],
    'n_steps': [5, 7],
    'gamma': [1.3, 1.5],
    'lambda_sparse': [1e-5, 1e-4],
    'lr': [1e-3, 2e-3]
}

# Generar todas las combinaciones posibles
keys, values = zip(*param_grid.items())
combinations = [dict(zip(keys, v)) for v in product(*values)]

best_score = 0
best_model = None
best_params = None

print(f"Probando {len(combinations)} combinaciones de hiperparámetros...\n")

for i, params in enumerate(combinations):
    print(f"Probando combinación {i+1}: {params}")
    
    model = TabNetClassifier(
        n_d=params['n_d'],
        n_a=params['n_a'],
        n_steps=params['n_steps'],
        gamma=params['gamma'],
        lambda_sparse=params['lambda_sparse'],
        optimizer_params=dict(lr=params['lr']),
        scheduler_params={"step_size": 10, "gamma": 0.9},
        mask_type='sparsemax',
        momentum=0.3,
        verbose=0
    )

    model.fit(
        X_train=X_train_res_scaled, y_train=y_train_res,
        eval_set=[(X_test_scaled, y_testset)],
        eval_metric=['accuracy'],
        max_epochs=150,
        patience=20,
        batch_size=512,
        virtual_batch_size=64
    )

    # Evaluar en test
    y_pred = model.predict(X_test_scaled)
    acc = accuracy_score(y_testset, y_pred)

    print(f"→ Accuracy: {acc:.4f}")

    if acc > best_score:
        best_score = acc
        best_model = model
        best_params = params

print("\n✅ Mejor combinación encontrada:")
print(best_params)
print(f"→ Accuracy: {best_score:.4f}")
# Out:
# Probando 64 combinaciones de hiperparámetros...
#
# Probando combinación 1: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 56 with best_epoch = 36 and best_val_0_accuracy = 0.54783
# → Accuracy: 0.5478
# Probando combinación 2: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 42 with best_epoch = 22 and best_val_0_accuracy = 0.63043
# → Accuracy: 0.6304
# Probando combinación 3: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 92 with best_epoch = 72 and best_val_0_accuracy = 0.65652
# → Accuracy: 0.6565
# Probando combinación 4: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 84 with best_epoch = 64 and best_val_0_accuracy = 0.71739
# → Accuracy: 0.7174
# Probando combinación 5: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 72 with best_epoch = 52 and best_val_0_accuracy = 0.5913
# → Accuracy: 0.5913
# Probando combinación 6: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 130 with best_epoch = 110 and best_val_0_accuracy = 0.84348
# → Accuracy: 0.8435
# Probando combinación 7: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 46 with best_epoch = 26 and best_val_0_accuracy = 0.56957
# → Accuracy: 0.5696
# Probando combinación 8: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 122 with best_epoch = 102 and best_val_0_accuracy = 0.81304
# → Accuracy: 0.8130
# Probando combinación 9: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 49 with best_epoch = 29 and best_val_0_accuracy = 0.5087
# → Accuracy: 0.5087
# Probando combinación 10: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 111 with best_epoch = 91 and best_val_0_accuracy = 0.72174
# → Accuracy: 0.7217
# Probando combinación 11: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 74 with best_epoch = 54 and best_val_0_accuracy = 0.57391
# → Accuracy: 0.5739
# Probando combinación 12: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 137 with best_epoch = 117 and best_val_0_accuracy = 0.8
# → Accuracy: 0.8000
# Probando combinación 13: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 93 with best_epoch = 73 and best_val_0_accuracy = 0.63043
# → Accuracy: 0.6304
# Probando combinación 14: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 104 with best_epoch = 84 and best_val_0_accuracy = 0.72174
# → Accuracy: 0.7217
# Probando combinación 15: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 122 with best_epoch = 102 and best_val_0_accuracy = 0.66087
# → Accuracy: 0.6609
# Probando combinación 16: {'n_d': 16, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 87 with best_epoch = 67 and best_val_0_accuracy = 0.65652
# → Accuracy: 0.6565
# Probando combinación 17: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 20 with best_epoch = 0 and best_val_0_accuracy = 0.17826
# → Accuracy: 0.1783
# Probando combinación 18: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 70 with best_epoch = 50 and best_val_0_accuracy = 0.62609
# → Accuracy: 0.6261
# Probando combinación 19: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 20 with best_epoch = 0 and best_val_0_accuracy = 0.17826
# → Accuracy: 0.1783
# Probando combinación 20: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 118 with best_epoch = 98 and best_val_0_accuracy = 0.73478
# → Accuracy: 0.7348
# Probando combinación 21: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 109 with best_epoch = 89 and best_val_0_accuracy = 0.66087
# → Accuracy: 0.6609
# Probando combinación 22: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 125 with best_epoch = 105 and best_val_0_accuracy = 0.72174
# → Accuracy: 0.7217
# Probando combinación 23: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 135 with best_epoch = 115 and best_val_0_accuracy = 0.63043
# → Accuracy: 0.6304
# Probando combinación 24: {'n_d': 16, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 71 with best_epoch = 51 and best_val_0_accuracy = 0.64783
# → Accuracy: 0.6478
# Probando combinación 25: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 143 with best_epoch = 123 and best_val_0_accuracy = 0.68261
# → Accuracy: 0.6826
# Probando combinación 26: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 147 and best_val_0_accuracy = 0.77391
# → Accuracy: 0.7739
# Probando combinación 27: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 51 with best_epoch = 31 and best_val_0_accuracy = 0.44348
# → Accuracy: 0.4435
# Probando combinación 28: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 141 and best_val_0_accuracy = 0.85652
# → Accuracy: 0.8565
# Probando combinación 29: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 115 with best_epoch = 95 and best_val_0_accuracy = 0.6087
# → Accuracy: 0.6087
# Probando combinación 30: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 142 and best_val_0_accuracy = 0.76957
# → Accuracy: 0.7696
# Probando combinación 31: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 111 with best_epoch = 91 and best_val_0_accuracy = 0.63043
# → Accuracy: 0.6304
# Probando combinación 32: {'n_d': 16, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 140 and best_val_0_accuracy = 0.8087
# → Accuracy: 0.8087
# Probando combinación 33: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
# Stop training because you reached max_epochs = 150 with best_epoch = 141 and best_val_0_accuracy = 0.75652
# → Accuracy: 0.7565
# Probando combinación 34: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 144 with best_epoch = 124 and best_val_0_accuracy = 0.85652
# → Accuracy: 0.8565
# Probando combinación 35: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 94 with best_epoch = 74 and best_val_0_accuracy = 0.66957
# → Accuracy: 0.6696
# Probando combinación 36: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 108 with best_epoch = 88 and best_val_0_accuracy = 0.74348
# → Accuracy: 0.7435
# Probando combinación 37: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 107 with best_epoch = 87 and best_val_0_accuracy = 0.65652
# → Accuracy: 0.6565
# Probando combinación 38: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 92 with best_epoch = 72 and best_val_0_accuracy = 0.75217
# → Accuracy: 0.7522
# Probando combinación 39: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 118 with best_epoch = 98 and best_val_0_accuracy = 0.69565
# → Accuracy: 0.6957
# Probando combinación 40: {'n_d': 24, 'n_a': 16, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 79 with best_epoch = 59 and best_val_0_accuracy = 0.70435
# → Accuracy: 0.7043
# Probando combinación 41: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 97 with best_epoch = 77 and best_val_0_accuracy = 0.65652
# → Accuracy: 0.6565
# Probando combinación 42: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 143 with best_epoch = 123 and best_val_0_accuracy = 0.78696
# → Accuracy: 0.7870
# Probando combinación 43: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 62 with best_epoch = 42 and best_val_0_accuracy = 0.46087
# → Accuracy: 0.4609
# Probando combinación 44: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 70 with best_epoch = 50 and best_val_0_accuracy = 0.71739
# → Accuracy: 0.7174
# Probando combinación 45: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 94 with best_epoch = 74 and best_val_0_accuracy = 0.61739
# → Accuracy: 0.6174
# Probando combinación 46: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 110 with best_epoch = 90 and best_val_0_accuracy = 0.72174
# → Accuracy: 0.7217
# Probando combinación 47: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 112 with best_epoch = 92 and best_val_0_accuracy = 0.62174
# → Accuracy: 0.6217
# Probando combinación 48: {'n_d': 24, 'n_a': 16, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 92 with best_epoch = 72 and best_val_0_accuracy = 0.7
# → Accuracy: 0.7000
# Probando combinación 49: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 132 with best_epoch = 112 and best_val_0_accuracy = 0.76087
# → Accuracy: 0.7609
# Probando combinación 50: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
# Stop training because you reached max_epochs = 150 with best_epoch = 147 and best_val_0_accuracy = 0.87826
# → Accuracy: 0.8783
# Probando combinación 51: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
# Stop training because you reached max_epochs = 150 with best_epoch = 142 and best_val_0_accuracy = 0.76957
# → Accuracy: 0.7696
# Probando combinación 52: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 119 with best_epoch = 99 and best_val_0_accuracy = 0.82174
# → Accuracy: 0.8217
# Probando combinación 53: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 82 with best_epoch = 62 and best_val_0_accuracy = 0.63478
# → Accuracy: 0.6348
# Probando combinación 54: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 108 with best_epoch = 88 and best_val_0_accuracy = 0.86522
# → Accuracy: 0.8652
# Probando combinación 55: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 82 with best_epoch = 62 and best_val_0_accuracy = 0.61739
# → Accuracy: 0.6174
# Probando combinación 56: {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 124 with best_epoch = 104 and best_val_0_accuracy = 0.85217
# → Accuracy: 0.8522
# Probando combinación 57: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.001}
# Stop training because you reached max_epochs = 150 with best_epoch = 136 and best_val_0_accuracy = 0.74348
# → Accuracy: 0.7435
# Probando combinación 58: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 135 with best_epoch = 115 and best_val_0_accuracy = 0.80435
# → Accuracy: 0.8043
# Probando combinación 59: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 112 with best_epoch = 92 and best_val_0_accuracy = 0.74348
# → Accuracy: 0.7435
# Probando combinación 60: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.3, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 106 with best_epoch = 86 and best_val_0_accuracy = 0.8087
# → Accuracy: 0.8087
# Probando combinación 61: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.001}
#
# Early stopping occurred at epoch 69 with best_epoch = 49 and best_val_0_accuracy = 0.56087
# → Accuracy: 0.5609
# Probando combinación 62: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 1e-05, 'lr': 0.002}
#
# Early stopping occurred at epoch 85 with best_epoch = 65 and best_val_0_accuracy = 0.72174
# → Accuracy: 0.7217
# Probando combinación 63: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.001}
#
# Early stopping occurred at epoch 92 with best_epoch = 72 and best_val_0_accuracy = 0.62609
# → Accuracy: 0.6261
# Probando combinación 64: {'n_d': 24, 'n_a': 24, 'n_steps': 7, 'gamma': 1.5, 'lambda_sparse': 0.0001, 'lr': 0.002}
#
# Early stopping occurred at epoch 99 with best_epoch = 79 and best_val_0_accuracy = 0.76087
# → Accuracy: 0.7609
#
# ✅ Mejor combinación encontrada:
# {'n_d': 24, 'n_a': 24, 'n_steps': 5, 'gamma': 1.3, 'lambda_sparse': 1e-05, 'lr': 0.002}
# → Accuracy: 0.8783

# %% [markdown]
# ## MÉTRICAS DEL MODELO TRAIN

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelBinarizer
import numpy as np

# Evaluar el mejor modelo sobre el conjunto de entrenamiento
train_pred = best_model.predict(X_train_res_scaled)
train_probs = best_model.predict_proba(X_train_res_scaled)

print("\n--- MÉTRICAS EN EL CONJUNTO DE ENTRENAMIENTO ---")
print('Accuracy:', accuracy_score(y_train_res, train_pred), '→', accuracy_score(y_train_res, train_pred)*100, '%')
print('Precisión:', precision_score(y_train_res, train_pred, average='macro'), '→', precision_score(y_train_res, train_pred, average='macro')*100, '%')
print('Recall (sensibilidad):', recall_score(y_train_res, train_pred, average='macro'), '→', recall_score(y_train_res, train_pred, average='macro')*100, '%')
print('F1-score:', f1_score(y_train_res, train_pred, average='macro'), '→', f1_score(y_train_res, train_pred, average='macro')*100, '%')

# AUC (manejo multiclase o binario)
if len(np.unique(y_train_res)) == 2:
    roc_auc = roc_auc_score(y_train_res, train_probs[:, 1])
else:
    roc_auc = roc_auc_score(LabelBinarizer().fit_transform(y_train_res), train_probs, multi_class='ovr')
print('ROC AUC:', roc_auc, '→', roc_auc*100, '%')

# MCC
print('Matthews Correlation Coefficient:', matthews_corrcoef(y_train_res, train_pred))
# Out:
# --- MÉTRICAS EN EL CONJUNTO DE ENTRENAMIENTO ---
# Accuracy: 0.928921568627451 → 92.8921568627451 %
# Precisión: 0.9295592103665365 → 92.95592103665365 %
# Recall (sensibilidad): 0.9289215686274511 → 92.89215686274511 %
# F1-score: 0.9285867657911967 → 92.85867657911967 %
# ROC AUC: 0.9871098255478662 → 98.71098255478663 %
# Matthews Correlation Coefficient: 0.9149734648130544

# %% [markdown]
# ## MÉTRICAS DEL MODELO TEST

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, classification_report, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelBinarizer

# Predicciones y probabilidades sobre el conjunto de prueba
test_pred = best_model.predict(X_test_scaled)
test_probs = best_model.predict_proba(X_test_scaled)

print("\n--- MÉTRICAS EN EL CONJUNTO DE PRUEBA ---")

print('Accuracy:', accuracy_score(y_testset, test_pred), '→', accuracy_score(y_testset, test_pred)*100, '%')
print('Precisión:', precision_score(y_testset, test_pred, average='weighted'), '→', precision_score(y_testset, test_pred, average='weighted')*100, '%')
print('Recall (sensibilidad):', recall_score(y_testset, test_pred, average='macro'), '→', recall_score(y_testset, test_pred, average='macro')*100, '%')
print('F1-score:', f1_score(y_testset, test_pred, average='weighted'), '→', f1_score(y_testset, test_pred, average='weighted')*100, '%')

# AUC
if len(np.unique(y_testset)) == 2:
    roc_auc = roc_auc_score(y_testset, test_probs[:, 1])
else:
    roc_auc = roc_auc_score(LabelBinarizer().fit_transform(y_testset), test_probs, multi_class='ovr')
print('ROC AUC:', roc_auc, '→', roc_auc*100, '%')

# MCC
print('Matthews Correlation Coefficient:', matthews_corrcoef(y_testset, test_pred), '→', matthews_corrcoef(y_testset, test_pred)*100, '%')

# Reporte de clasificación
print("\nClassification Report (TEST):")
print(classification_report(y_testset, test_pred, target_names=le.classes_.astype(str)))
# Out:
# --- MÉTRICAS EN EL CONJUNTO DE PRUEBA ---
# Accuracy: 0.8782608695652174 → 87.82608695652175 %
# Precisión: 0.8841829321782994 → 88.41829321782994 %
# Recall (sensibilidad): 0.8851776289159449 → 88.51776289159449 %
# F1-score: 0.8789957243640997 → 87.89957243640997 %
# ROC AUC: 0.976905206596045 → 97.6905206596045 %
# Matthews Correlation Coefficient: 0.8431237361973124 → 84.31237361973125 %
#
# Classification Report (TEST):
#                                 precision    recall  f1-score   support
#
#                        Healthy       0.95      0.91      0.93        64
#         Iron deficiency anemia       0.89      0.89      0.89        38
#              Macrocytic anemia       0.60      1.00      0.75         3
#  Normocytic hypochromic anemia       0.85      0.76      0.80        54
# Normocytic normochromic anemia       0.89      0.95      0.92        61
#        Other microcytic anemia       0.62      0.80      0.70        10
#
#                       accuracy                           0.88       230
#                      macro avg       0.80      0.89      0.83       230
#                   weighted avg       0.88      0.88      0.88       230
